# %% [markdown]
# # Iris

# %%
from Iris.TreeID3 import gridSearch
gridSearch()
# Out:
# Melhor max_depth: 3
# Melhor min_samples_split: 2
# Melhor accuracy: 0.9733

# %%
from Iris.irisDataSetInterface import main
main()
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.10.12)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# └── [depth=0] petallength < 3.0
#     ├── Leaf: class => Iris-setosa
#     └── [depth=1] petalwidth < 1.8
#         ├── [depth=2] petallength < 5.0
#         │   ├── Leaf: class => Iris-versicolor
#         │   └── Leaf: class => Iris-virginica
#         └── [depth=2] petallength < 4.9
#             ├── Leaf: class => Iris-virginica
#             └── Leaf: class => Iris-virginica
# Accuracy:  0.9733333333333334
# F1-Score:  0.9732999164578112
# AUC:  0.9796666666666667
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /home/diogo/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3587: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# # Tree Connect Four

# %%
from Tree_Connect4.TreeID3Connect4 import *
gridSearch()
# Out:
# Gráfico salvo como 'gridsearch_connect4.png'
#
# Melhores parâmetros encontrados:
# Max Depth: 12
# Min Sample Size: 10
# Min Sample Split: 15

# %%
createTree()
# Out:
# accuracy on test set:  83.19747769916319 %
#               precision    recall  f1-score   support
#
#     coluna_0      0.792     0.814     0.803       758
#     coluna_1      0.763     0.801     0.782      1252
#     coluna_2      0.882     0.733     0.800      2539
#     coluna_3      0.867     0.949     0.907      3937
#     coluna_4      0.779     0.831     0.804      2560
#     coluna_5      0.839     0.701     0.764      1211
#     coluna_6      0.836     0.835     0.836       747
#
#     accuracy                          0.832     13004
#    macro avg      0.823     0.809     0.814     13004
# weighted avg      0.834     0.832     0.830     13004
# (<Tree_Connect4.TreeID3Connect4.Tree at 0x7e3bd96c3880>,
#  0.8319747769916949,
#  0.8135934552711944)

# %%
from Tree_Connect4.TreeConnect4Interface import main
main()
# Out:
# └── [depth=0] legal_c3 = 0
#     └── [depth=1] p1_r3c2 = 0
#         └── [depth=2] legal_c4 = 0
#             └── [depth=3] last_c2 = 0
#                 └── [depth=4] p1_r3c6 = 0
#                     └── [depth=5] last_c5 = 0
#                         └── [depth=6] p1_r2c2 = 0
#                             └── [depth=7] p1_r2c6 = 0
#                                 └── [depth=8] p0_r0c6 = 0
#                                     └── [depth=9] p0_r0c0 = 0
#                                         └── Leaf: class => 0
#                                         ├── Leaf: class => 6
#                                     ├── Leaf: class => 6
#                                 ├── [depth=8] p1_r3c0 = 0
#                                 │   └── Leaf: class => 0
#                                 │   ├── Leaf: class => 1
#                             ├── [depth=7] legal_c1 = 0
#                             │   └── [depth=8] p0_r2c0 = 0
# ...

# %% [markdown]
# # Game

# %%
from Tree_Connect4.TreeID3Connect4 import *
from Game.Interface import Interface

game_interface = Interface()
game_interface.run()
